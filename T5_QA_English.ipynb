# %% [markdown]
# <a href="https://colab.research.google.com/github/SalmaAlmasry/Graduation-Project-Question-Answering-System-/blob/main/T5_QA_English.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers==3.0.0
# Out:
# ...
#      |████████████████████████████████| 754 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 43.5 MB/s
# ...
#      |████████████████████████████████| 895 kB 66.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 44.3 MB/s
# ...

# %%
# !python -m nltk.downloader punkt
# Out:
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !git clone https://github.com/patil-suraj/question_generation.git
# Out:
# Cloning into 'question_generation'...
# remote: Enumerating objects: 268, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 268 (delta 101), reused 95 (delta 95), pack-reused 156
# Receiving objects: 100% (268/268), 289.86 KiB | 3.81 MiB/s, done.
# Resolving deltas: 100% (147/147), done.

# %%
text = " Hi I am a Student at FCAIH. I am trying to implement a question-answering system using t5 model."
text2 = "I hope every thing goes well in this GP"

# %% [markdown]
# Small Model

# %%
# %cd question_generation
# Out:
# /content/question_generation

# %%
from pipelines import pipeline

# %%
nlp = pipeline("multitask-qa-qg")
# Out:
# Downloading:   0%|          | 0.00/656 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]

# %%
nlp({
  "question": "Who am I ?",
  "context": text
})
# Out:
# 'Student'

# %% [markdown]
# Base Model

# %%
nlp = pipeline("multitask-qa-qg", model="valhalla/t5-base-qa-qg-hl")
# Out:
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
nlp({
    "question": "What am I trying to do?",
     "context": text
})
# Out:
# 'implement a question-answering system using t5 model'

# %%
nlp({
    "question": "What do I hope for?",
     "context": text2
})
# Out:
# 'every thing goes well'
